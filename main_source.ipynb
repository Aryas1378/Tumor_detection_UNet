# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
# import keras.backend as K
from tensorflow.keras import backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import Normalization, Rescaling, StringLookup, CategoryEncoding

# %%
TRAIN_DATASET_PATH = "./BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
old_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# renaming the file
try:
    os.rename(old_name, new_name)
    print("File has been re-named successfully!")
except:
    print("File is already renamed!")
# Out:
# File is already renamed!

# %%
# load .nii file as a numpy array
test_image_flair = nib.load(TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1854.603271484375

# %%
scaler = MinMaxScaler()

# %%
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# Mask won't be rescaled
test_image_seg = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)

# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories);

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
# Print data distribution (Train: 68%, Test: 12%, Val: 20%)

print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 250
# Validation length: 74
# Test length: 45

# %%
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume that we will include
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
   
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
       
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            t1ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];

        # Generate masks
        y[y==4] = 3
        mask = tf.one_hot(y, 4)
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation) # Displaying segmentation
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()


# Retrieve the batch from the training generator
X_batch, Y_batch = training_generator[8]

# Extract Flair, T1CE, and segmentation from the batch
flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convert one-hot encoded to categorical

# Extract the 50th slice from Flair, T1CE, and segmentation
slice_index = 60  # Indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Display the 50th slice and its segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)

# %% [markdown]
# Loss Function and Evaluation Metrics

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

# %%
# Define per class evaluation of dice coef
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)

# %% [markdown]
# Each function includes a small constant (`epsilon`) to avoid division by zero.

# %%
# Computing Precision
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision


# Computing Sensitivity
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %% [markdown]
# UNet

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ## Build and Plot the Model

# %%
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)

# %% [markdown]
# ## Set up callbacks

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                                      patience=2, min_lr=0.000001, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath='model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                                    verbose=1, save_best_only=True, save_weights_only=True),
    keras.callbacks.CSVLogger('training.log', separator=',', append=False)
]

# %% [markdown]
# # Train and Save the Model

# %%
print(training_generator)
print(valid_generator)
print(callbacks)
print(print(train_ids))
# Out:
# <__main__.DataGenerator object at 0x0000020554DE2B40>
# <__main__.DataGenerator object at 0x0000020554DA73B0>
# [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x0000020554D5C7A0>, <keras.src.callbacks.model_checkpoint.ModelCheckpoint object at 0x0000020554939F70>, <keras.src.callbacks.csv_logger.CSVLogger object at 0x00000205549C3890>]
# ['BraTS20_Training_346', 'BraTS20_Training_292', 'BraTS20_Training_050', 'BraTS20_Training_128', 'BraTS20_Training_031', 'BraTS20_Training_230', 'BraTS20_Training_163', 'BraTS20_Training_125', 'BraTS20_Training_134', 'BraTS20_Training_200', 'BraTS20_Training_133', 'BraTS20_Training_201', 'BraTS20_Training_269', 'BraTS20_Training_100', 'BraTS20_Training_049', 'BraTS20_Training_306', 'BraTS20_Training_099', 'BraTS20_Training_147', 'BraTS20_Training_162', 'BraTS20_Training_024', 'BraTS20_Training_351', 'BraTS20_Training_327', 'BraTS20_Training_308', 'BraTS20_Training_318', 'BraTS20_Training_304', 'BraTS20_Training_006', 'BraTS20_Training_015', 'BraTS20_Training_007', 'BraTS20_Training_150', 'BraTS20_Training_123', 'BraTS20_Training_142', 'BraTS20_Training_360', 'BraTS20_Training_273', 'BraTS20_Training_074', 'BraTS20_Training_102', 'BraTS20_Training_008', 'BraTS20_Training_305', 'BraTS20_Training_070', 'BraTS20_Training_061', 'BraTS20_Training_321', 'BraTS20_Training_341', 'BraTS20_Training_354', 'BraTS20_Training_279', 'BraTS20_Training_113', 'BraTS20_Training_089', 'BraTS20_Training_313', 'BraTS20_Training_118', 'BraTS20_Training_359', 'BraTS20_Training_220', 'BraTS20_Training_079', 'BraTS20_Training_035', 'BraTS20_Training_223', 'BraTS20_Training_038', 'BraTS20_Training_291', 'BraTS20_Training_154', 'BraTS20_Training_032', 'BraTS20_Training_316', 'BraTS20_Training_214', 'BraTS20_Training_122', 'BraTS20_Training_192', 'BraTS20_Training_348', 'BraTS20_Training_335', 'BraTS20_Training_110', 'BraTS20_Training_289', 'BraTS20_Training_356', 'BraTS20_Training_252', 'BraTS20_Training_211', 'BraTS20_Training_098', 'BraTS20_Training_009', 'BraTS20_Training_161', 'BraTS20_Training_096', 'BraTS20_Training_347', 'BraTS20_Training_136', 'BraTS20_Training_242', 'BraTS20_Training_277', 'BraTS20_Training_352', 'BraTS20_Training_263', 'BraTS20_Training_364', 'BraTS20_Training_180', 'BraTS20_Training_037', 'BraTS20_Training_097', 'BraTS20_Training_187', 'BraTS20_Training_240', 'BraTS20_Training_282', 'BraTS20_Training_302', 'BraTS20_Training_073', 'BraTS20_Training_069', 'BraTS20_Training_280', 'BraTS20_Training_119', 'BraTS20_Training_281', 'BraTS20_Training_334', 'BraTS20_Training_349', 'BraTS20_Training_324', 'BraTS20_Training_329', 'BraTS20_Training_333', 'BraTS20_Training_266', 'BraTS20_Training_157', 'BraTS20_Training_146', 'BraTS20_Training_116', 'BraTS20_Training_095', 'BraTS20_Training_080', 'BraTS20_Training_267', 'BraTS20_Training_151', 'BraTS20_Training_004', 'BraTS20_Training_272', 'BraTS20_Training_312', 'BraTS20_Training_027', 'BraTS20_Training_179', 'BraTS20_Training_185', 'BraTS20_Training_235', 'BraTS20_Training_064', 'BraTS20_Training_156', 'BraTS20_Training_139', 'BraTS20_Training_165', 'BraTS20_Training_357', 'BraTS20_Training_126', 'BraTS20_Training_299', 'BraTS20_Training_101', 'BraTS20_Training_343', 'BraTS20_Training_332', 'BraTS20_Training_319', 'BraTS20_Training_149', 'BraTS20_Training_194', 'BraTS20_Training_022', 'BraTS20_Training_205', 'BraTS20_Training_058', 'BraTS20_Training_019', 'BraTS20_Training_172', 'BraTS20_Training_182', 'BraTS20_Training_033', 'BraTS20_Training_260', 'BraTS20_Training_083', 'BraTS20_Training_137', 'BraTS20_Training_239', 'BraTS20_Training_195', 'BraTS20_Training_363', 'BraTS20_Training_295', 'BraTS20_Training_233', 'BraTS20_Training_003', 'BraTS20_Training_047', 'BraTS20_Training_018', 'BraTS20_Training_001', 'BraTS20_Training_120', 'BraTS20_Training_053', 'BraTS20_Training_090', 'BraTS20_Training_040', 'BraTS20_Training_043', 'BraTS20_Training_237', 'BraTS20_Training_307', 'BraTS20_Training_081', 'BraTS20_Training_178', 'BraTS20_Training_104', 'BraTS20_Training_021', 'BraTS20_Training_315', 'BraTS20_Training_016', 'BraTS20_Training_301', 'BraTS20_Training_014', 'BraTS20_Training_176', 'BraTS20_Training_029', 'BraTS20_Training_044', 'BraTS20_Training_232', 'BraTS20_Training_213', 'BraTS20_Training_245', 'BraTS20_Training_330', 'BraTS20_Training_065', 'BraTS20_Training_048', 'BraTS20_Traini ...
# None

# %%
K.clear_session()
history =  model.fit(training_generator,
                    epochs=35,
                    steps_per_epoch=len(train_ids),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )
# Out:
# WARNING:tensorflow:From C:\Users\Aryas\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/35
# C:\Users\Aryas\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9438 - dice_coef: 0.2426 - dice_coef_edema: 0.0782 - dice_coef_enhancing: 0.0224 - dice_coef_necrotic: 0.0392 - loss: 0.3049 - mean_io_u: 0.4676 - precision: 0.9336 - sensitivity: 0.8668 - specificity: 0.9927
# Epoch 1: val_loss improved from inf to 0.07397, saving model to model_.01-0.073966.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3128s 12s/step - accuracy: 0.9440 - dice_coef: 0.2427 - dice_coef_edema: 0.0783 - dice_coef_enhancing: 0.0224 - dice_coef_necrotic: 0.0393 - loss: 0.3042 - mean_io_u: 0.4678 - precision: 0.9338 - sensitivity: 0.8671 - specificity: 0.9928 - val_accuracy: 0.9840 - val_dice_coef: 0.2827 - val_dice_coef_edema: 0.2046 - val_dice_coef_enhancing: 0.0935 - val_dice_coef_necrotic: 0.1115 - val_loss: 0.0740 - val_mean_io_u: 0.4304 - val_precision: 0.9856 - val_sensitivity: 0.9805 - val_specificity: 0.9952 - learning_rate: 0.0010
# Epoch 2/35
# d:\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# Epoch 2: val_loss did not improve from 0.07397
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 213s 851ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9840 - val_dice_coef: 0.2827 - val_dice_coef_edema: 0.2046 - val_dice_coef_enhancing: 0.0935 - val_dice_coef_necrotic: 0.1115 - val_loss: 0.0740 - val_mean_io_u: 0.4304 - val_precision: 0.9856 - val_sensitivity: 0.9805 - val_specificity: 0.9952 - learning_rate: 0.0010
# Epoch 3/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9822 - dice_coef: 0.2820 - dice_coef_edema: 0.1692 - dice_coef_enhancing: 0.0664 - dice_coef_necrotic: 0.0933 - loss: 0.0747 - mean_io_u: 0.5499 - precision: 0.9836 - sensitivity: 0.9810 - specificity: 0.9945
# Epoch 3: val_loss improved from 0.07397 to 0.07216, saving model to model_.03-0.072156.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3116s 12s/step - accuracy: 0.9822 - dice_coef: 0.2820 - dice_coef_edema: 0.1692 - dice_coef_enhancing: 0.0664 - dice_coef_necrotic: 0.0933 - loss: 0.0747 - mean_io_u: 0.5500 - precision: 0.9836 - sensitivity: 0.9810 - specificity: 0.9945 - val_accuracy: 0.9840 - val_dice_coef: 0.2828 - val_dice_coef_edema: 0.2014 - val_dice_coef_enhancing: 0.0738 - val_dice_coef_necrotic: 0.1020 - val_loss: 0.0722 - val_mean_io_u: 0.5394 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - learning_rate: 0.0010
# Epoch 4/35
#
# Epoch 4: val_loss did not improve from 0.07216
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 204s 815ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9840 - val_dice_coef: 0.2828 - val_dice_coef_edema: 0.2014 - val_dice_coef_enhancing: 0.0738 - val_dice_coef_necrotic: 0.1020 - val_loss: 0.0722 - val_mean_io_u: 0.5394 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - learning_rate: 0.0010
# Epoch 5/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.9846 - dice_coef: 0.2785 - dice_coef_edema: 0.1582 - dice_coef_enhancing: 0.0480 - dice_coef_necrotic: 0.0862 - loss: 0.0680 - mean_io_u: 0.5716 - precision: 0.9849 - sensitivity: 0.9832 - specificity: 0.9950
# Epoch 5: val_loss improved from 0.07216 to 0.06753, saving model to model_.05-0.067526.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3401s 14s/step - accuracy: 0.9846 - dice_coef: 0.2785 - dice_coef_edema: 0.1582 - dice_coef_enhancing: 0.0480 - dice_coef_necrotic: 0.0862 - loss: 0.0680 - mean_io_u: 0.5715 - precision: 0.9849 - sensitivity: 0.9832 - specificity: 0.9950 - val_accuracy: 0.9840 - val_dice_coef: 0.2875 - val_dice_coef_edema: 0.2401 - val_dice_coef_enhancing: 0.0746 - val_dice_coef_necrotic: 0.1217 - val_loss: 0.0675 - val_mean_io_u: 0.4035 - val_precision: 0.9849 - val_sensitivity: 0.9831 - val_specificity: 0.9950 - learning_rate: 0.0010
# Epoch 6/35
#
# Epoch 6: val_loss improved from 0.06753 to 0.06753, saving model to model_.06-0.067526.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 215s 860ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9840 - val_dice_coef: 0.2875 - val_dice_coef_edema: 0.2401 - val_dice_coef_enhancing: 0.0746 - val_dice_coef_necrotic: 0.1217 - val_loss: 0.0675 - val_mean_io_u: 0.4035 - val_precision: 0.9849 - val_sensitivity: 0.9831 - val_specificity: 0.9950 - learning_rate: 0.0010
# Epoch 7/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9822 - dice_coef: 0.2873 - dice_coef_edema: 0.1921 - dice_coef_enhancing: 0.0576 - dice_coef_necrotic: 0.1139 - loss: 0.0705 - mean_io_u: 0.4916 - precision: 0.9838 - sensitivity: 0.9796 - specificity: 0.9946
# Epoch 7: val_loss improved from 0.06753 to 0.05629, saving model to model_.07-0.056292.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3034s 12s/step - accuracy: 0.9822 - dice_coef: 0.2873 - dice_coef_edema: 0.1921 - dice_coef_enhancing: 0.0576 - dice_coef_necrotic: 0.1139 - loss: 0.0704 - mean_io_u: 0.4915 - precision: 0.9838 - sensitivity: 0.9796 - specificity: 0.9946 - val_accuracy: 0.9840 - val_dice_coef: 0.3037 - val_dice_coef_edema: 0.2282 - val_dice_coef_enhancing: 0.1014 - val_dice_coef_necrotic: 0.1290 - val_loss: 0.0563 - val_mean_io_u: 0.4716 - val_precision: 0.9855 - val_sensitivity: 0.9835 - val_specificity: 0.9952 - learning_rate: 0.0010
# Epoch 8/35
#
# Epoch 8: val_loss did not improve from 0.05629
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 199s 797ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9840 - val_dice_coef: 0.3037 - val_dice_coef_edema: 0.2282 - val_dice_coef_enhancing: 0.1014 - val_dice_coef_necrotic: 0.1290 - val_loss: 0.0563 - val_mean_io_u: 0.4716 - val_precision: 0.9855 - val_sensitivity: 0.9835 - val_specificity: 0.9952 - learning_rate: 0.0010
# Epoch 9/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9831 - dice_coef: 0.2961 - dice_coef_edema: 0.2147 - dice_coef_enhancing: 0.0862 - dice_coef_necrotic: 0.1159 - loss: 0.0629 - mean_io_u: 0.4676 - precision: 0.9860 - sensitivity: 0.9817 - specificity: 0.9953
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 9: val_loss did not improve from 0.05629
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2964s 12s/step - accuracy: 0.9831 - dice_coef: 0.2961 - dice_coef_edema: 0.2147 - dice_coef_enhancing: 0.0862 - dice_coef_necrotic: 0.1159 - loss: 0.0629 - mean_io_u: 0.4677 - precision: 0.9860 - sensitivity: 0.9817 - specificity: 0.9953 - val_accuracy: 0.9840 - val_dice_coef: 0.2990 - val_dice_coef_edema: 0.2460 - val_dice_coef_enhancing: 0.0783 - val_dice_coef_necrotic: 0.1205 - val_loss: 0.0582 - val_mean_io_u: 0.4166 - val_precision: 0.9854 - val_sensitivity: 0.9833 - val_specificity: 0.9952 - learning_rate: 0.0010
# Epoch 10/35
#
# Epoch 10: val_loss did not improve from 0.05629
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 215s 860ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9840 - val_dice_coef: 0.2990 - val_dice_coef_edema: 0.2460 - val_dice_coef_enhancing: 0.0783 - val_dice_coef_necrotic: 0.1205 - val_loss: 0.0582 - val_mean_io_u: 0.4166 - val_precision: 0.9854 - val_sensitivity: 0.9833 - val_specificity: 0.9952 - learning_rate: 2.0000e-04
# Epoch 11/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9846 - dice_coef: 0.3071 - dice_coef_edema: 0.2495 - dice_coef_enhancing: 0.1011 - dice_coef_necrotic: 0.1369 - loss: 0.0531 - mean_io_u: 0.4387 - precision: 0.9874 - sensitivity: 0.9833 - specificity: 0.9958
# Epoch 11: val_loss improved from 0.05629 to 0.05092, saving model to model_.11-0.050918.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3069s 12s/step - accuracy: 0.9846 - dice_coef: 0.3072 - dice_coef_edema: 0.2496 - dice_coef_enhancing: 0.1012 - dice_coef_necrotic: 0.1370 - loss: 0.0531 - mean_io_u: 0.4388 - precision: 0.9874 - sensitivity: 0.9833 - specificity: 0.9958 - val_accuracy: 0.9852 - val_dice_coef: 0.3286 - val_dice_coef_edema: 0.2988 - val_dice_coef_enhancing: 0.1791 - val_dice_coef_necrotic: 0.1588 - val_loss: 0.0509 - val_mean_io_u: 0.4760 - val_precision: 0.9895 - val_sensitivity: 0.9819 - val_specificity: 0.9965 - learning_rate: 2.0000e-04
# Epoch 12/35
#
# Epoch 12: val_loss improved from 0.05092 to 0.05092, saving model to model_.12-0.050918.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 233s 932ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9852 - val_dice_coef: 0.3286 - val_dice_coef_edema: 0.2988 - val_dice_coef_enhancing: 0.1791 - val_dice_coef_necrotic: 0.1588 - val_loss: 0.0509 - val_mean_io_u: 0.4760 - val_precision: 0.9895 - val_sensitivity: 0.9819 - val_specificity: 0.9965 - learning_rate: 2.0000e-04
# Epoch 13/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9843 - dice_coef: 0.3404 - dice_coef_edema: 0.3269 - dice_coef_enhancing: 0.1857 - dice_coef_necrotic: 0.1908 - loss: 0.0497 - mean_io_u: 0.4779 - precision: 0.9902 - sensitivity: 0.9798 - specificity: 0.9966
# Epoch 13: val_loss improved from 0.05092 to 0.04525, saving model to model_.13-0.045252.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3111s 12s/step - accuracy: 0.9843 - dice_coef: 0.3404 - dice_coef_edema: 0.3269 - dice_coef_enhancing: 0.1857 - dice_coef_necrotic: 0.1908 - loss: 0.0497 - mean_io_u: 0.4779 - precision: 0.9902 - sensitivity: 0.9798 - specificity: 0.9966 - val_accuracy: 0.9869 - val_dice_coef: 0.3500 - val_dice_coef_edema: 0.3845 - val_dice_coef_enhancing: 0.2267 - val_dice_coef_necrotic: 0.1894 - val_loss: 0.0453 - val_mean_io_u: 0.4321 - val_precision: 0.9916 - val_sensitivity: 0.9819 - val_specificity: 0.9971 - learning_rate: 2.0000e-04
# Epoch 14/35
#
# Epoch 14: val_loss improved from 0.04525 to 0.04525, saving model to model_.14-0.045252.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 211s 845ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9869 - val_dice_coef: 0.3500 - val_dice_coef_edema: 0.3845 - val_dice_coef_enhancing: 0.2267 - val_dice_coef_necrotic: 0.1894 - val_loss: 0.0453 - val_mean_io_u: 0.4321 - val_precision: 0.9916 - val_sensitivity: 0.9819 - val_specificity: 0.9971 - learning_rate: 2.0000e-04
# Epoch 15/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9864 - dice_coef: 0.3562 - dice_coef_edema: 0.3807 - dice_coef_enhancing: 0.2052 - dice_coef_necrotic: 0.2138 - loss: 0.0439 - mean_io_u: 0.4493 - precision: 0.9909 - sensitivity: 0.9818 - specificity: 0.9969
# Epoch 15: val_loss improved from 0.04525 to 0.04285, saving model to model_.15-0.042848.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3044s 12s/step - accuracy: 0.9864 - dice_coef: 0.3563 - dice_coef_edema: 0.3808 - dice_coef_enhancing: 0.2053 - dice_coef_necrotic: 0.2139 - loss: 0.0439 - mean_io_u: 0.4493 - precision: 0.9909 - sensitivity: 0.9818 - specificity: 0.9969 - val_accuracy: 0.9875 - val_dice_coef: 0.3744 - val_dice_coef_edema: 0.3984 - val_dice_coef_enhancing: 0.2518 - val_dice_coef_necrotic: 0.2164 - val_loss: 0.0428 - val_mean_io_u: 0.4832 - val_precision: 0.9902 - val_sensitivity: 0.9848 - val_specificity: 0.9967 - learning_rate: 2.0000e-04
# Epoch 16/35
#
# Epoch 16: val_loss improved from 0.04285 to 0.04285, saving model to model_.16-0.042848.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 215s 858ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9875 - val_dice_coef: 0.3744 - val_dice_coef_edema: 0.3984 - val_dice_coef_enhancing: 0.2518 - val_dice_coef_necrotic: 0.2164 - val_loss: 0.0428 - val_mean_io_u: 0.4832 - val_precision: 0.9902 - val_sensitivity: 0.9848 - val_specificity: 0.9967 - learning_rate: 2.0000e-04
# Epoch 17/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9872 - dice_coef: 0.3857 - dice_coef_edema: 0.4426 - dice_coef_enhancing: 0.2712 - dice_coef_necrotic: 0.2605 - loss: 0.0402 - mean_io_u: 0.4792 - precision: 0.9910 - sensitivity: 0.9837 - specificity: 0.9969
# Epoch 17: val_loss improved from 0.04285 to 0.03999, saving model to model_.17-0.039995.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3184s 13s/step - accuracy: 0.9872 - dice_coef: 0.3857 - dice_coef_edema: 0.4427 - dice_coef_enhancing: 0.2712 - dice_coef_necrotic: 0.2606 - loss: 0.0402 - mean_io_u: 0.4792 - precision: 0.9910 - sensitivity: 0.9837 - specificity: 0.9969 - val_accuracy: 0.9882 - val_dice_coef: 0.3889 - val_dice_coef_edema: 0.4597 - val_dice_coef_enhancing: 0.3021 - val_dice_coef_necrotic: 0.2468 - val_loss: 0.0400 - val_mean_io_u: 0.4568 - val_precision: 0.9910 - val_sensitivity: 0.9853 - val_specificity: 0.9969 - learning_rate: 2.0000e-04
# Epoch 18/35
#
# Epoch 18: val_loss did not improve from 0.03999
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 214s 857ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9882 - val_dice_coef: 0.3889 - val_dice_coef_edema: 0.4597 - val_dice_coef_enhancing: 0.3021 - val_dice_coef_necrotic: 0.2468 - val_loss: 0.0400 - val_mean_io_u: 0.4568 - val_precision: 0.9910 - val_sensitivity: 0.9853 - val_specificity: 0.9969 - learning_rate: 2.0000e-04
# Epoch 19/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9871 - dice_coef: 0.4040 - dice_coef_edema: 0.4896 - dice_coef_enhancing: 0.3130 - dice_coef_necrotic: 0.2861 - loss: 0.0391 - mean_io_u: 0.4816 - precision: 0.9911 - sensitivity: 0.9833 - specificity: 0.9969
# Epoch 19: val_loss improved from 0.03999 to 0.03680, saving model to model_.19-0.036801.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3007s 12s/step - accuracy: 0.9871 - dice_coef: 0.4040 - dice_coef_edema: 0.4896 - dice_coef_enhancing: 0.3131 - dice_coef_necrotic: 0.2861 - loss: 0.0391 - mean_io_u: 0.4816 - precision: 0.9911 - sensitivity: 0.9833 - specificity: 0.9969 - val_accuracy: 0.9893 - val_dice_coef: 0.4355 - val_dice_coef_edema: 0.5178 - val_dice_coef_enhancing: 0.4754 - val_dice_coef_necrotic: 0.2758 - val_loss: 0.0368 - val_mean_io_u: 0.5205 - val_precision: 0.9928 - val_sensitivity: 0.9854 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 20/35
#
# Epoch 20: val_loss improved from 0.03680 to 0.03680, saving model to model_.20-0.036801.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 227s 906ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9893 - val_dice_coef: 0.4355 - val_dice_coef_edema: 0.5178 - val_dice_coef_enhancing: 0.4754 - val_dice_coef_necrotic: 0.2758 - val_loss: 0.0368 - val_mean_io_u: 0.5205 - val_precision: 0.9928 - val_sensitivity: 0.9854 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 21/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.9891 - dice_coef: 0.4522 - dice_coef_edema: 0.5500 - dice_coef_enhancing: 0.4281 - dice_coef_necrotic: 0.3301 - loss: 0.0316 - mean_io_u: 0.5346 - precision: 0.9924 - sensitivity: 0.9858 - specificity: 0.9974
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 21: val_loss did not improve from 0.03680
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3858s 15s/step - accuracy: 0.9891 - dice_coef: 0.4521 - dice_coef_edema: 0.5499 - dice_coef_enhancing: 0.4281 - dice_coef_necrotic: 0.3301 - loss: 0.0316 - mean_io_u: 0.5346 - precision: 0.9924 - sensitivity: 0.9858 - specificity: 0.9974 - val_accuracy: 0.9889 - val_dice_coef: 0.4259 - val_dice_coef_edema: 0.4489 - val_dice_coef_enhancing: 0.4135 - val_dice_coef_necrotic: 0.2548 - val_loss: 0.0397 - val_mean_io_u: 0.5201 - val_precision: 0.9911 - val_sensitivity: 0.9865 - val_specificity: 0.9970 - learning_rate: 2.0000e-04
# Epoch 22/35
#
# Epoch 22: val_loss did not improve from 0.03680
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 363s 1s/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9889 - val_dice_coef: 0.4259 - val_dice_coef_edema: 0.4489 - val_dice_coef_enhancing: 0.4135 - val_dice_coef_necrotic: 0.2548 - val_loss: 0.0397 - val_mean_io_u: 0.5201 - val_precision: 0.9911 - val_sensitivity: 0.9865 - val_specificity: 0.9970 - learning_rate: 4.0000e-05
# Epoch 23/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9891 - dice_coef: 0.4490 - dice_coef_edema: 0.5654 - dice_coef_enhancing: 0.4216 - dice_coef_necrotic: 0.3254 - loss: 0.0316 - mean_io_u: 0.5049 - precision: 0.9923 - sensitivity: 0.9857 - specificity: 0.9973
# Epoch 23: val_loss improved from 0.03680 to 0.03265, saving model to model_.23-0.032649.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3343s 13s/step - accuracy: 0.9891 - dice_coef: 0.4490 - dice_coef_edema: 0.5655 - dice_coef_enhancing: 0.4217 - dice_coef_necrotic: 0.3255 - loss: 0.0316 - mean_io_u: 0.5050 - precision: 0.9923 - sensitivity: 0.9857 - specificity: 0.9973 - val_accuracy: 0.9903 - val_dice_coef: 0.4748 - val_dice_coef_edema: 0.5704 - val_dice_coef_enhancing: 0.5369 - val_dice_coef_necrotic: 0.3355 - val_loss: 0.0326 - val_mean_io_u: 0.5329 - val_precision: 0.9933 - val_sensitivity: 0.9870 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 24/35
#
# Epoch 24: val_loss improved from 0.03265 to 0.03265, saving model to model_.24-0.032649.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 237s 948ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9903 - val_dice_coef: 0.4748 - val_dice_coef_edema: 0.5704 - val_dice_coef_enhancing: 0.5369 - val_dice_coef_necrotic: 0.3355 - val_loss: 0.0326 - val_mean_io_u: 0.5329 - val_precision: 0.9933 - val_sensitivity: 0.9870 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 25/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9902 - dice_coef: 0.4731 - dice_coef_edema: 0.5783 - dice_coef_enhancing: 0.4608 - dice_coef_necrotic: 0.3796 - loss: 0.0287 - mean_io_u: 0.5294 - precision: 0.9930 - sensitivity: 0.9869 - specificity: 0.9976
# Epoch 25: val_loss improved from 0.03265 to 0.03185, saving model to model_.25-0.031853.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3143s 13s/step - accuracy: 0.9902 - dice_coef: 0.4731 - dice_coef_edema: 0.5784 - dice_coef_enhancing: 0.4609 - dice_coef_necrotic: 0.3796 - loss: 0.0287 - mean_io_u: 0.5294 - precision: 0.9930 - sensitivity: 0.9869 - specificity: 0.9976 - val_accuracy: 0.9905 - val_dice_coef: 0.4808 - val_dice_coef_edema: 0.5830 - val_dice_coef_enhancing: 0.5366 - val_dice_coef_necrotic: 0.3400 - val_loss: 0.0319 - val_mean_io_u: 0.5436 - val_precision: 0.9932 - val_sensitivity: 0.9875 - val_specificity: 0.9976 - learning_rate: 4.0000e-05
# Epoch 26/35
#
# Epoch 26: val_loss did not improve from 0.03185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 209s 836ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9905 - val_dice_coef: 0.4808 - val_dice_coef_edema: 0.5830 - val_dice_coef_enhancing: 0.5366 - val_dice_coef_necrotic: 0.3400 - val_loss: 0.0319 - val_mean_io_u: 0.5436 - val_precision: 0.9932 - val_sensitivity: 0.9875 - val_specificity: 0.9976 - learning_rate: 4.0000e-05
# Epoch 27/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9899 - dice_coef: 0.4824 - dice_coef_edema: 0.5921 - dice_coef_enhancing: 0.4791 - dice_coef_necrotic: 0.3862 - loss: 0.0288 - mean_io_u: 0.5432 - precision: 0.9927 - sensitivity: 0.9868 - specificity: 0.9975
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 27: val_loss did not improve from 0.03185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3021s 12s/step - accuracy: 0.9899 - dice_coef: 0.4824 - dice_coef_edema: 0.5921 - dice_coef_enhancing: 0.4792 - dice_coef_necrotic: 0.3862 - loss: 0.0288 - mean_io_u: 0.5432 - precision: 0.9927 - sensitivity: 0.9868 - specificity: 0.9975 - val_accuracy: 0.9902 - val_dice_coef: 0.4840 - val_dice_coef_edema: 0.6095 - val_dice_coef_enhancing: 0.5148 - val_dice_coef_necrotic: 0.3552 - val_loss: 0.0319 - val_mean_io_u: 0.5348 - val_precision: 0.9925 - val_sensitivity: 0.9875 - val_specificity: 0.9974 - learning_rate: 4.0000e-05
# Epoch 28/35
#
# Epoch 28: val_loss did not improve from 0.03185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 207s 826ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9902 - val_dice_coef: 0.4840 - val_dice_coef_edema: 0.6095 - val_dice_coef_enhancing: 0.5148 - val_dice_coef_necrotic: 0.3552 - val_loss: 0.0319 - val_mean_io_u: 0.5348 - val_precision: 0.9925 - val_sensitivity: 0.9875 - val_specificity: 0.9974 - learning_rate: 8.0000e-06
# Epoch 29/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9905 - dice_coef: 0.4788 - dice_coef_edema: 0.5994 - dice_coef_enhancing: 0.4673 - dice_coef_necrotic: 0.3797 - loss: 0.0267 - mean_io_u: 0.5348 - precision: 0.9927 - sensitivity: 0.9878 - specificity: 0.9975
# Epoch 29: val_loss improved from 0.03185 to 0.03132, saving model to model_.29-0.031323.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3016s 12s/step - accuracy: 0.9905 - dice_coef: 0.4788 - dice_coef_edema: 0.5994 - dice_coef_enhancing: 0.4674 - dice_coef_necrotic: 0.3798 - loss: 0.0267 - mean_io_u: 0.5348 - precision: 0.9927 - sensitivity: 0.9878 - specificity: 0.9975 - val_accuracy: 0.9906 - val_dice_coef: 0.4900 - val_dice_coef_edema: 0.5974 - val_dice_coef_enhancing: 0.5445 - val_dice_coef_necrotic: 0.3557 - val_loss: 0.0313 - val_mean_io_u: 0.5492 - val_precision: 0.9930 - val_sensitivity: 0.9879 - val_specificity: 0.9976 - learning_rate: 8.0000e-06
# Epoch 30/35
#
# Epoch 30: val_loss improved from 0.03132 to 0.03132, saving model to model_.30-0.031323.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 209s 838ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9906 - val_dice_coef: 0.4900 - val_dice_coef_edema: 0.5974 - val_dice_coef_enhancing: 0.5445 - val_dice_coef_necrotic: 0.3557 - val_loss: 0.0313 - val_mean_io_u: 0.5492 - val_precision: 0.9930 - val_sensitivity: 0.9879 - val_specificity: 0.9976 - learning_rate: 8.0000e-06
# Epoch 31/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9907 - dice_coef: 0.4916 - dice_coef_edema: 0.5982 - dice_coef_enhancing: 0.4844 - dice_coef_necrotic: 0.4101 - loss: 0.0267 - mean_io_u: 0.5465 - precision: 0.9930 - sensitivity: 0.9879 - specificity: 0.9976
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 31: val_loss improved from 0.03132 to 0.03131, saving model to model_.31-0.031307.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3024s 12s/step - accuracy: 0.9907 - dice_coef: 0.4917 - dice_coef_edema: 0.5983 - dice_coef_enhancing: 0.4844 - dice_coef_necrotic: 0.4101 - loss: 0.0267 - mean_io_u: 0.5465 - precision: 0.9930 - sensitivity: 0.9879 - specificity: 0.9976 - val_accuracy: 0.9906 - val_dice_coef: 0.4924 - val_dice_coef_edema: 0.6052 - val_dice_coef_enhancing: 0.5328 - val_dice_coef_necrotic: 0.3574 - val_loss: 0.0313 - val_mean_io_u: 0.5552 - val_precision: 0.9927 - val_sensitivity: 0.9882 - val_specificity: 0.9975 - learning_rate: 8.0000e-06
# Epoch 32/35
#
# Epoch 32: val_loss improved from 0.03131 to 0.03131, saving model to model_.32-0.031307.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 209s 836ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9906 - val_dice_coef: 0.4924 - val_dice_coef_edema: 0.6052 - val_dice_coef_enhancing: 0.5328 - val_dice_coef_necrotic: 0.3574 - val_loss: 0.0313 - val_mean_io_u: 0.5552 - val_precision: 0.9927 - val_sensitivity: 0.9882 - val_specificity: 0.9975 - learning_rate: 1.6000e-06
# Epoch 33/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9907 - dice_coef: 0.4983 - dice_coef_edema: 0.6167 - dice_coef_enhancing: 0.4859 - dice_coef_necrotic: 0.4182 - loss: 0.0261 - mean_io_u: 0.5522 - precision: 0.9929 - sensitivity: 0.9879 - specificity: 0.9975
# Epoch 33: val_loss improved from 0.03131 to 0.03114, saving model to model_.33-0.031136.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3017s 12s/step - accuracy: 0.9907 - dice_coef: 0.4983 - dice_coef_edema: 0.6167 - dice_coef_enhancing: 0.4859 - dice_coef_necrotic: 0.4181 - loss: 0.0261 - mean_io_u: 0.5522 - precision: 0.9929 - sensitivity: 0.9879 - specificity: 0.9975 - val_accuracy: 0.9907 - val_dice_coef: 0.4928 - val_dice_coef_edema: 0.6045 - val_dice_coef_enhancing: 0.5406 - val_dice_coef_necrotic: 0.3590 - val_loss: 0.0311 - val_mean_io_u: 0.5543 - val_precision: 0.9929 - val_sensitivity: 0.9881 - val_specificity: 0.9975 - learning_rate: 1.6000e-06
# Epoch 34/35
#
# Epoch 34: val_loss did not improve from 0.03114
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 210s 839ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9907 - val_dice_coef: 0.4928 - val_dice_coef_edema: 0.6045 - val_dice_coef_enhancing: 0.5406 - val_dice_coef_necrotic: 0.3590 - val_loss: 0.0311 - val_mean_io_u: 0.5543 - val_precision: 0.9929 - val_sensitivity: 0.9881 - val_specificity: 0.9975 - learning_rate: 1.6000e-06
# Epoch 35/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.9909 - dice_coef: 0.4983 - dice_coef_edema: 0.6259 - dice_coef_enhancing: 0.5065 - dice_coef_necrotic: 0.4002 - loss: 0.0254 - mean_io_u: 0.5480 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 35: val_loss improved from 0.03114 to 0.03110, saving model to model_.35-0.031103.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3023s 12s/step - accuracy: 0.9909 - dice_coef: 0.4983 - dice_coef_edema: 0.6259 - dice_coef_enhancing: 0.5065 - dice_coef_necrotic: 0.4002 - loss: 0.0255 - mean_io_u: 0.5480 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976 - val_accuracy: 0.9907 - val_dice_coef: 0.4931 - val_dice_coef_edema: 0.6032 - val_dice_coef_enhancing: 0.5438 - val_dice_coef_necrotic: 0.3594 - val_loss: 0.0311 - val_mean_io_u: 0.5554 - val_precision: 0.9929 - val_sensitivity: 0.9881 - val_specificity: 0.9976 - learning_rate: 1.6000e-06

# %%
model.save("my_model.keras")

# %% [markdown]
# # Load the Trained Model

# %%
model = keras.models.load_model('./my_model.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)

# %%
history = pd.read_csv('./training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()

# %%
# Compile a model and load our saved weights
import tensorflow as tf

IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

best_saved_model.load_weights('model_.35-0.031103.weights.h5')
# Out:
# C:\Users\Aryas\AppData\Roaming\Python\Python312\site-packages\keras\src\saving\saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 94 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %%
def imageLoader(self, path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*self.c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*self.c,:,:,1] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*self.c] = image[:,:,j+VOLUME_START_AT]
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata()


    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    return model.predict(X/np.max(X), verbose=1)

# %%
def showPredictsById(case, start_slice = 60):
    path = f"./BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50))

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')

    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes predicted')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()

# %%
showPredictsById(case=test_ids[0][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step

# %%
showPredictsById(case=test_ids[1][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 622ms/step

# %%
showPredictsById(case=test_ids[2][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 564ms/step

# %%
showPredictsById(case=test_ids[3][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 644ms/step

# %%
showPredictsById(case=test_ids[4][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 575ms/step

# %%
showPredictsById(case=test_ids[5][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 674ms/step

# %%
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 622ms/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - all classes')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - Not Tumor')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 716ms/step
# Patient number:  BraTS20_Training_326

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 665ms/step
# Patient number:  BraTS20_Training_342

# %%
show_predicted_segmentations(test_ids, 65, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 602ms/step
# Patient number:  BraTS20_Training_303

# %%
case = test_ids[3][-3:]
path = f"./BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 593ms/step

# %% [markdown]
# # 13. Evaluation
#
# Let's call the `evaluate()` function to evaluate the performance of our model on our test dataset:

# %%
# Evaluate the model on the test data
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# C:\Users\Aryas\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 193s 4s/step - accuracy: 0.9891 - dice_coef: 0.5116 - dice_coef_edema: 0.6135 - dice_coef_enhancing: 0.5449 - dice_coef_necrotic: 0.4358 - loss: 0.0331 - mean_io_u_4: 0.5620 - precision: 0.9919 - sensitivity: 0.9860 - specificity: 0.9972
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0337
# Accuracy : 0.989
# MeanIOU : 0.5017
# Dice coefficient : 0.5858
# Precision : 0.5473
# Sensitivity : 0.425
# Specificity : 0.5623
# Dice coef Necrotic : 0.9919
# Dice coef Edema : 0.9858
# Dice coef Enhancing : 0.9972
